# %%
#import needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
def complete_zip(zip_code_series):
    #zip_code_series.astype(str)
    
    for zip in zip_code_series:
        if len(zip) == 3:
            zip = '00' + zip  
        elif len(zip) == 4:
            zip = '0' + zip
        else:
            pass
    
    return zip_code_series

# %%
def complete_zip2(zip):
    #zip_code_series.astype(str)
        if len(zip) == 3:
            zip = '00' + zip  
        elif len(zip) == 4:
            zip = '0' + zip
        else:
            pass
    
    #return zip_code_series

# %%
#pull in data and take a high level look
dataA = pd.read_csv('Data/tasksheetdataa.csv')
dataZ = pd.read_csv('Data/tasksheetdataz.csv')

# %%
dataA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fileid    33120 non-null  object
#  1   stusab    33120 non-null  object
#  2   chariter  33120 non-null  int64
#  3   cifsn     33120 non-null  int64
#  4   logrecno  33120 non-null  int64
#  5   p0010001  33120 non-null  int64
#  6   sumlev    33120 non-null  int64
#  7   geocomp   33120 non-null  int64
#  8   zcta5     33120 non-null  int64
#  9   arealand  33120 non-null  int64
#  10  areawatr  33120 non-null  int64
#  11  name      33120 non-null  object
#  12  funcstat  33120 non-null  object
#  13  pop100    33120 non-null  int64
#  14  hu100     33120 non-null  int64
#  15  intptlat  33120 non-null  float64
#  16  intptlon  33120 non-null  float64
#  17  lsadc     33120 non-null  object
# dtypes: float64(2), int64(11), object(5)
# memory usage: 4.5+ MB

# %%
#dataA['test'] = complete_zip(dataA['zcta5'])

# %%
#dataA['test']

# %%
#dataA['zcta5'] = dataA['zcta5'].str.zfill(5)

# %%
# for zip in dataA['zcta5']:
#     dataA['zcta5'][zip] = complete_zip2(dataA['zcta5'][zip])

# %%
# dataA['zcta5'] = dataA['zcta5'].apply(lambda x:complete_zip(x))
# dataA['zcta5']

# %%
#dataA.apply(lambda x:complete_zip(x))

# %%
dataA['zcta5']
# Out:
# 0          601
# 1          602
# 2          603
# 3          606
# 4          610
#          ...
# 33115    99923
# 33116    99925
# 33117    99926
# 33118    99927
# 33119    99929
# Name: zcta5, Length: 33120, dtype: int64

# %%
dataA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fileid    33120 non-null  object
#  1   stusab    33120 non-null  object
#  2   chariter  33120 non-null  int64
#  3   cifsn     33120 non-null  int64
#  4   logrecno  33120 non-null  int64
#  5   p0010001  33120 non-null  int64
#  6   sumlev    33120 non-null  int64
#  7   geocomp   33120 non-null  int64
#  8   zcta5     33120 non-null  int64
#  9   arealand  33120 non-null  int64
#  10  areawatr  33120 non-null  int64
#  11  name      33120 non-null  object
#  12  funcstat  33120 non-null  object
#  13  pop100    33120 non-null  int64
#  14  hu100     33120 non-null  int64
#  15  intptlat  33120 non-null  float64
#  16  intptlon  33120 non-null  float64
#  17  lsadc     33120 non-null  object
# dtypes: float64(2), int64(11), object(5)
# memory usage: 4.5+ MB

# %%
dataA.head()
# Out:
#   fileid stusab  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  zcta5  \
# 0  UR1US     US         0      1    479832     18570     860        0    601
# 1  UR1US     US         0      1    479836     41520     860        0    602
# 2  UR1US     US         0      1    479839     54689     860        0    603
# 3  UR1US     US         0      1    479842      6615     860        0    606
# 4  UR1US     US         0      1    479847     29016     860        0    610
#
#     arealand  areawatr         name funcstat  pop100  hu100   intptlat  \
# 0  166659789    799296  ZCTA5 00601        S   18570   7744  18.180556
# 1   79288158   4446273  ZCTA5 00602        S   41520  18073  18.362268
# 2   81880442    183425  ZCTA5 00603        S   54689  25653  18.455183
# 3  109580061     12487  ZCTA5 00606        S    6615   2877  18.158345
# 4   93021467   4172001  ZCTA5 00610        S   29016  12618  18.290955
#
#     intptlon lsadc
# 0 -66.749961    Z5
# 1 -67.176130    Z5
# 2 -67.119887    Z5
# 3 -66.932911    Z5
# 4 -67.125868    Z5

# %%
dataZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41469 entries, 0 to 41468
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         41469 non-null  object
#  1   zip             41469 non-null  int64
#  2   city            41469 non-null  object
#  3   state           40956 non-null  object
#  4   stusab          40958 non-null  object
#  5   county          40958 non-null  object
#  6   county_fips     40958 non-null  float64
#  7   community       1 non-null      object
#  8   community_code  1 non-null      float64
#  9   latitude        41469 non-null  float64
#  10  longitude       41469 non-null  float64
#  11  accuracy        40937 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 3.8+ MB

# %%
dataZ.head()
# Out:
#   country    zip        city   state stusab          county  county_fips  \
# 0      US  99553      Akutan  Alaska     AK  Aleutians East         13.0
# 1      US  99571    Cold Bay  Alaska     AK  Aleutians East         13.0
# 2      US  99583  False Pass  Alaska     AK  Aleutians East         13.0
# 3      US  99612   King Cove  Alaska     AK  Aleutians East         13.0
# 4      US  99661  Sand Point  Alaska     AK  Aleutians East         13.0
#
#   community  community_code  latitude  longitude  accuracy
# 0       NaN             NaN   54.1430  -165.7854       1.0
# 1       NaN             NaN   55.1858  -162.7211       1.0
# 2       NaN             NaN   54.8542  -163.4113       1.0
# 3       NaN             NaN   55.0628  -162.3056       1.0
# 4       NaN             NaN   55.3192  -160.4914       1.0

# %%
dataZ[dataZ['zip'] < 1000]
# Out:
#       country  zip        city     state stusab   county  county_fips  \
# 26775      US  501  Holtsville  New York     NY  Suffolk        103.0
# 26776      US  544  Holtsville  New York     NY  Suffolk        103.0
#
#       community  community_code  latitude  longitude  accuracy
# 26775       NaN             NaN   40.8154   -73.0451       4.0
# 26776       NaN             NaN   40.8154   -73.0451       4.0

# %%
dataA['zcta5'] = dataA['zcta5'].astype(str)
dataZ['zip'] = dataZ['zip'].astype(str)
dataA['zcta5'] = dataA['zcta5'].str.zfill(5)
dataZ['zip'] = dataZ['zip'].str.zfill(5)

# %%
# expected_zip_code_length = 5
# pd.Series(["0"] * len(dataA['zcta5']) * (expected_zip_code_length - dataA['zcta5'].str.len()) + dataA['zcta5'])

# %%
#dataA['zipA'] = dataA['name'].str[-5:]

# %%
#dataZ['zip'] = dataZ['zip'].astype(int)

# %%
merged = pd.merge(dataA, dataZ, left_on = 'zcta5', right_on = 'zip', how = 'inner')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32974 entries, 0 to 32973
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fileid          32974 non-null  object
#  1   stusab_x        32974 non-null  object
#  2   chariter        32974 non-null  int64
#  3   cifsn           32974 non-null  int64
#  4   logrecno        32974 non-null  int64
#  5   p0010001        32974 non-null  int64
#  6   sumlev          32974 non-null  int64
#  7   geocomp         32974 non-null  int64
#  8   zcta5           32974 non-null  object
#  9   arealand        32974 non-null  int64
#  10  areawatr        32974 non-null  int64
#  11  name            32974 non-null  object
#  12  funcstat        32974 non-null  object
#  13  pop100          32974 non-null  int64
#  14  hu100           32974 non-null  int64
#  15  intptlat        32974 non-null  float64
#  16  intptlon        32974 non-null  float64
#  17  lsadc           32974 non-null  object
#  18  country         32974 non-null  object
#  19  zip             32974 non-null  object
#  20  city            32974 non-null  object
#  21  state           32972 non-null  object
#  22  stusab_y        32972 non-null  object
#  23  county          32972 non-null  object
#  24  county_fips     32972 non-null  float64
#  25  community       1 non-null      object
#  26  community_code  1 non-null      float64
#  27  latitude        32974 non-null  float64
#  28  longitude       32974 non-null  float64
#  29  accuracy        32974 non-null  float64
# dtypes: float64(7), int64(10), object(13)
# memory usage: 7.8+ MB

# %%
#a - Texas is the state with the most 5 digit zip codes (1,935)
merged['state'].value_counts().sort_values(ascending=False)
# Out:
# Texas                   1935
# Pennsylvania            1795
# New York                1794
# California              1761
# Illinois                1383
# Ohio                    1195
# Missouri                1023
# Michigan                 986
# Florida                  983
# Iowa                     934
# Virginia                 896
# Minnesota                884
# North Carolina           808
# Indiana                  775
# Wisconsin                774
# Kentucky                 767
# Georgia                  735
# West Virginia            706
# Kansas                   697
# Oklahoma                 648
# Alabama                  642
# Tennessee                628
# Washington               596
# New Jersey               595
# Arkansas                 591
# Nebraska                 581
# Massachusetts            537
# Colorado                 525
# Louisiana                515
# Maryland                 468
# Maine                    432
# South Carolina           424
# Mississippi              423
# Oregon                   417
# Arizona                  405
# North Dakota             383
# South Dakota             371
# New Mexico               368
# Montana                  361
# Utah                     287
# Connecticut              282
# Idaho                    278
# Vermont                  255
# New Hampshire            248
# Alaska                   238
# Wyoming                  178
# Nevada                   175
# Hawaii                    94
# Rhode Island              77
# Delaware                  67
# District of Columbia      52
# Name: state, dtype: int64

# %%
#Used to test for change in latitude/longitude values
merged[merged['state'] == 'Alaska'].head(1)
merged[merged['state'] == 'Minnesota'].head(1)
merged[merged['state'] == 'Texas'].head(1)
merged[merged['state'] == 'Oregon'].head(1)
# Out:
#       fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 31723  UR1US       US         0      1    586622       229     860        0
#
#        zcta5   arealand  ...      city   state stusab_y  county  county_fips  \
# 31723  97001  770309402  ...  Antelope  Oregon       OR   Wasco         65.0
#
#        community  community_code latitude longitude accuracy
# 31723        NaN             NaN  44.8892 -120.7914      4.0
#
# [1 rows x 30 columns]

# %%
#b(i) - 04631 is the most easterly zip
merged[merged['longitude']== merged['longitude'].max()]
# Out:
#      fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 1129  UR1US       US         0      1    483733      1331     860        0
#
#       zcta5  arealand  ...      city  state stusab_y      county  county_fips  \
# 1129  04631   9455354  ...  Eastport  Maine       ME  Washington         29.0
#
#       community  community_code latitude longitude accuracy
# 1129        NaN             NaN    44.92  -67.0074      4.0
#
# [1 rows x 30 columns]

# %%
merged_no_AK = merged[merged['state'] != 'Alaska']

# %%
#b(ii) - 96769 is the most westerly zip (excluding Alaska)
merged_no_AK[merged['longitude']== merged_no_AK['longitude'].min()]
# Out:
#       fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 31680  UR1US       US         0      1    586499       464     860        0
#
#        zcta5   arealand  ...      city   state stusab_y  county  county_fips  \
# 31680  96769  193525234  ...  Makaweli  Hawaii       HI   Kauai          7.0
#
#        community  community_code latitude longitude accuracy
# 31680        NaN             NaN  21.9454 -159.9214      1.0
#
# [1 rows x 30 columns]

# %%
#b(iii) - 56711 is the most northerly zip (excluding Alaska)
merged_no_AK[merged['latitude']== merged_no_AK['latitude'].max()]
# Out:
#       fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 19123  UR1US       US         0      1    544425        96     860        0
#
#        zcta5  arealand  ...         city      state stusab_y  \
# 19123  56711  48964391  ...  Angle Inlet  Minnesota       MN
#
#                   county  county_fips  community  community_code latitude  \
# 19123  Lake of the Woods         77.0        NaN             NaN  49.3453
#
#       longitude accuracy
# 19123  -95.0627      4.0
#
# [1 rows x 30 columns]

# %%
merged_has_population = merged[merged['p0010001'] > 0]

# %%
merged_has_population['land per person'] = merged_has_population['arealand'] / merged_has_population['p0010001']

# %%
merged_has_population['persons per thousand land units'] = (merged_has_population['p0010001'] / merged_has_population['arealand']) * 1000

# %%
#c Zip code 20052 has the highest population density at 67 persons per thousand land units
merged_has_population[merged_has_population['persons per thousand land units'] == merged_has_population['persons per thousand land units'].max()]
# Out:
#      fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 6105  UR1US       US         0      1    499507       470     860        0
#
#       zcta5  arealand  ...  stusab_y                county county_fips  \
# 6105  20052      7062  ...        DC  District of Columbia         1.0
#
#       community  community_code  latitude  longitude accuracy land per person  \
# 6105        NaN             NaN   38.9001   -77.0479      4.0       15.025532
#
#      persons per thousand land units
# 6105                       66.553384
#
# [1 rows x 32 columns]

# %%
#c Zip code 20052 has the highest population density at only 15 land units per person on average
merged_has_population[merged_has_population['land per person']== merged_has_population['land per person'].min()]
# Out:
#      fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 6105  UR1US       US         0      1    499507       470     860        0
#
#       zcta5  arealand  ...  stusab_y                county county_fips  \
# 6105  20052      7062  ...        DC  District of Columbia         1.0
#
#       community  community_code  latitude  longitude accuracy land per person  \
# 6105        NaN             NaN   38.9001   -77.0479      4.0       15.025532
#
#      persons per thousand land units
# 6105                       66.553384
#
# [1 rows x 32 columns]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32974 entries, 0 to 32973
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fileid          32974 non-null  object
#  1   stusab_x        32974 non-null  object
#  2   chariter        32974 non-null  int64
#  3   cifsn           32974 non-null  int64
#  4   logrecno        32974 non-null  int64
#  5   p0010001        32974 non-null  int64
#  6   sumlev          32974 non-null  int64
#  7   geocomp         32974 non-null  int64
#  8   zcta5           32974 non-null  object
#  9   arealand        32974 non-null  int64
#  10  areawatr        32974 non-null  int64
#  11  name            32974 non-null  object
#  12  funcstat        32974 non-null  object
#  13  pop100          32974 non-null  int64
#  14  hu100           32974 non-null  int64
#  15  intptlat        32974 non-null  float64
#  16  intptlon        32974 non-null  float64
#  17  lsadc           32974 non-null  object
#  18  country         32974 non-null  object
#  19  zip             32974 non-null  object
#  20  city            32974 non-null  object
#  21  state           32972 non-null  object
#  22  stusab_y        32972 non-null  object
#  23  county          32972 non-null  object
#  24  county_fips     32972 non-null  float64
#  25  community       1 non-null      object
#  26  community_code  1 non-null      float64
#  27  latitude        32974 non-null  float64
#  28  longitude       32974 non-null  float64
#  29  accuracy        32974 non-null  float64
# dtypes: float64(7), int64(10), object(13)
# memory usage: 8.8+ MB

# %%
merged['zip3'] = 0

# %%
for i in range(0,len(merged)):
     merged['zip3'][i] = merged['zip'][i][0:3]

# %%
merged
# Out:
#       fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 0      UR1US       US         0      1    480306     16769     860        0
# 1      UR1US       US         0      1    480309     29049     860        0
# 2      UR1US       US         0      1    480313     10372     860        0
# 3      UR1US       US         0      1    480316      5079     860        0
# 4      UR1US       US         0      1    480319     14649     860        0
# ...      ...      ...       ...    ...       ...       ...     ...      ...
# 32969  UR1US       US         0      1    590570        87     860        0
# 32970  UR1US       US         0      1    590573       819     860        0
# 32971  UR1US       US         0      1    590576      1460     860        0
# 32972  UR1US       US         0      1    590579        94     860        0
# 32973  UR1US       US         0      1    590582      2338     860        0
#
#        zcta5    arealand  ...          state stusab_y                  county  \
# 0      01001    29635470  ...  Massachusetts       MA                 Hampden
# 1      01002   142556362  ...  Massachusetts       MA               Hampshire
# 2      01003     1842384  ...  Massachusetts       MA               Hampshire
# 3      01005   114586903  ...  Massachusetts       MA               Worcester
# 4      01007   136345999  ...  Massachusetts       MA               Hampshire
# ...      ...         ...  ...            ...      ...                     ...
# 32969  99923    35937519  ...         Alaska       AK   Prince of Wales-Hyder
# 32970  99925   144503281  ...         Alaska       AK   Prince of Wales-Hyder
# 32971  99926   343947256  ...         Alaska       AK   Prince of Wales-Hyder
# 32972  99927   589688205  ...         Alaska       AK   Prince of Wales-Hyder
# 32973  99929  5598556684  ...         Alaska       AK  Wrangell-Petersburg (C
#
#        county_fips  community  community_code  latitude longitude accuracy  \
# 0             13.0        NaN             NaN   42.0702  -72.6227      4.0
# 1             15.0        NaN             NaN   42.3671  -72.4646      4.0
# 2             15.0        NaN             NaN   42.3919  -72.5248      4.0
# 3             27.0        NaN             NaN   42.4097  -72.1084      4.0
# 4             15.0        NaN             NaN   42.2751  -72.4110      4.0
# ...            ...        ...             ...       ...       ...      ...
# 32969        198.0        NaN             NaN   55.9169 -130.0247      1.0
# 32970        198.0        NaN             NaN   55.5526 -133.0555      4.0
# 32971        198.0        NaN             NaN   55.1215 -131.5790      4.0
# 32972        198.0        NaN             NaN   56.3528 -133.6211      4.0
# 32973        280.0        NaN             NaN   56.4335 -132.3529      4.0
#
#       zip3
# 0      010
# 1      010
# 2      010
# 3      010
# 4      010
# ...    ...
# 32969  999
# 32970  999
# 32971  999
# 32972  999
# 32973  999
#
# [32974 rows x 31 columns]

# %%
zip3_state = merged[['zip3','state']]

# %%
zip3_state
# Out:
#       zip3          state
# 0      010  Massachusetts
# 1      010  Massachusetts
# 2      010  Massachusetts
# 3      010  Massachusetts
# 4      010  Massachusetts
# ...    ...            ...
# 32969  999         Alaska
# 32970  999         Alaska
# 32971  999         Alaska
# 32972  999         Alaska
# 32973  999         Alaska
#
# [32974 rows x 2 columns]

# %%
zip3_state.drop_duplicates(inplace=True)

# %%
zip3_state
# Out:
#       zip3          state
# 0      010  Massachusetts
# 63     011  Massachusetts
# 76     012  Massachusetts
# 108    013  Massachusetts
# 137    014  Massachusetts
# ...    ...            ...
# 32736  995         Alaska
# 32793  996         Alaska
# 32874  997         Alaska
# 32949  998         Alaska
# 32963  999         Alaska
#
# [894 rows x 2 columns]

# %%
#zip3_state[zip3_state['state'].isna()==True]
zip3_state[zip3_state['zip3'] == '968']
# Out:
#       zip3   state
# 31704  968  Hawaii
# 31720  968     NaN

# %%
#zip3_state['zip3'].isduplicated().sum()

# %%
#d(i) - 063 and 834 are mapped to more than one state
zip3_state.groupby('zip3').count().sort_values(by = 'state',ascending=False)
# Out:
#       state
# zip3
# 063       2
# 834       2
# 010       1
# 654       1
# 641       1
# ...     ...
# 326       1
# 327       1
# 328       1
# 329       1
# 999       1
#
# [891 rows x 1 columns]

# %%
#zip3_state[zip3_state.groupby('zip3')['state'].count() > 1]

# %%
#205/739 [codes not in table A] 968[should drop nan]
merged[['city','state']][merged['zip3'] == '063']
# Out:
#                   city        state
# 1654        New London  Connecticut
# 1655            Baltic  Connecticut
# 1656        Canterbury  Connecticut
# 1657   Central Village  Connecticut
# 1658         East Lyme  Connecticut
# 1659            Bozrah  Connecticut
# 1660       Gales Ferry  Connecticut
# 1661            Gilman  Connecticut
# 1662           Ledyard  Connecticut
# 1663            Groton  Connecticut
# 1664           Hanover  Connecticut
# 1665       Jewett City  Connecticut
# 1666         Montville  Connecticut
# 1667            Moosup  Connecticut
# 1668            Mystic  Connecticut
# 1669           Niantic  Connecticut
# 1670  North Stonington  Connecticut
# 1671           Norwich  Connecticut
# 1672           Preston  Connecticut
# 1673           Oakdale  Connecticut
# 1674          Old Lyme  Connecticut
# 1675             Oneco  Connecticut
# 1676        Plainfield  Connecticut
# 1677       Quaker Hill  Connecticut
# 1678        South Lyme  Connecticut
# 1679          Sterling  Connecticut
# 1680        Stonington  Connecticut
# 1681         Pawcatuck  Connecticut
# 1682         Taftville  Connecticut
# 1683        Uncasville  Connecticut
# 1684         Voluntown  Connecticut
# 1685         Waterford  Connecticut
# 1686          Wauregan  Connecticut
# 1687            Yantic  Connecticut
# 1688    Fishers Island     New York

# %%
#d(ii) - the incongrous cities are Fisher's Island in New York and Alta in Wyoming
merged[['city','state']][merged['zip3'] == '834']
# Out:
#                 city    state
# 28441    Idaho Falls    Idaho
# 28442    Idaho Falls    Idaho
# 28443    Idaho Falls    Idaho
# 28444    Idaho Falls    Idaho
# 28445           Alta  Wyoming
# 28446         Ashton    Idaho
# 28447        Chester    Idaho
# 28448         Driggs    Idaho
# 28449         Dubois    Idaho
# 28450           Felt    Idaho
# 28451          Hamer    Idaho
# 28452           Iona    Idaho
# 28453          Irwin    Idaho
# 28454    Island Park    Idaho
# 28455     Lewisville    Idaho
# 28456      Macks Inn    Idaho
# 28457          Menan    Idaho
# 28458      Monteview    Idaho
# 28459        Newdale    Idaho
# 28460        Rexburg    Idaho
# 28461          Rigby    Idaho
# 28462          Ririe    Idaho
# 28463        Roberts    Idaho
# 28464  Saint Anthony    Idaho
# 28465        Spencer    Idaho
# 28466     Sugar City    Idaho
# 28467    Swan Valley    Idaho
# 28468       Terreton    Idaho
# 28469          Teton    Idaho
# 28470        Tetonia    Idaho
# 28471           Ucon    Idaho
# 28472         Victor    Idaho
# 28473        Rexburg    Idaho
# 28474         Carmen    Idaho
# 28475   Gibbonsville    Idaho
# 28476        Leadore    Idaho
# 28477          Lemhi    Idaho
# 28478     North Fork    Idaho
# 28479         Salmon    Idaho
# 28480         Tendoy    Idaho
# 28481          Shoup    Idaho

# %%
merged['state'].isna().sum()
# Out:
# 2

# %%
merged
# Out:
#       fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 0      UR1US       US         0      1    480306     16769     860        0
# 1      UR1US       US         0      1    480309     29049     860        0
# 2      UR1US       US         0      1    480313     10372     860        0
# 3      UR1US       US         0      1    480316      5079     860        0
# 4      UR1US       US         0      1    480319     14649     860        0
# ...      ...      ...       ...    ...       ...       ...     ...      ...
# 32969  UR1US       US         0      1    590570        87     860        0
# 32970  UR1US       US         0      1    590573       819     860        0
# 32971  UR1US       US         0      1    590576      1460     860        0
# 32972  UR1US       US         0      1    590579        94     860        0
# 32973  UR1US       US         0      1    590582      2338     860        0
#
#        zcta5    arealand  ...          state stusab_y                  county  \
# 0      01001    29635470  ...  Massachusetts       MA                 Hampden
# 1      01002   142556362  ...  Massachusetts       MA               Hampshire
# 2      01003     1842384  ...  Massachusetts       MA               Hampshire
# 3      01005   114586903  ...  Massachusetts       MA               Worcester
# 4      01007   136345999  ...  Massachusetts       MA               Hampshire
# ...      ...         ...  ...            ...      ...                     ...
# 32969  99923    35937519  ...         Alaska       AK   Prince of Wales-Hyder
# 32970  99925   144503281  ...         Alaska       AK   Prince of Wales-Hyder
# 32971  99926   343947256  ...         Alaska       AK   Prince of Wales-Hyder
# 32972  99927   589688205  ...         Alaska       AK   Prince of Wales-Hyder
# 32973  99929  5598556684  ...         Alaska       AK  Wrangell-Petersburg (C
#
#        county_fips  community  community_code  latitude longitude accuracy  \
# 0             13.0        NaN             NaN   42.0702  -72.6227      4.0
# 1             15.0        NaN             NaN   42.3671  -72.4646      4.0
# 2             15.0        NaN             NaN   42.3919  -72.5248      4.0
# 3             27.0        NaN             NaN   42.4097  -72.1084      4.0
# 4             15.0        NaN             NaN   42.2751  -72.4110      4.0
# ...            ...        ...             ...       ...       ...      ...
# 32969        198.0        NaN             NaN   55.9169 -130.0247      1.0
# 32970        198.0        NaN             NaN   55.5526 -133.0555      4.0
# 32971        198.0        NaN             NaN   55.1215 -131.5790      4.0
# 32972        198.0        NaN             NaN   56.3528 -133.6211      4.0
# 32973        280.0        NaN             NaN   56.4335 -132.3529      4.0
#
#       zip3
# 0      010
# 1      010
# 2      010
# 3      010
# 4      010
# ...    ...
# 32969  999
# 32970  999
# 32971  999
# 32972  999
# 32973  999
#
# [32974 rows x 31 columns]

# %%
#create dataset without these two rows
merged_2 = merged.drop([1688,28445])

# %%
#Fishers Island in New York and Alta - there are 3 altas LOL
# rows_to_drop = merged[ (merged['city'] == 'Fishers Island') | (merged['city'] == 'Alta') ].index
# rows_to_drop
#merged.drop(rows_to_drop , inplace=True)
# indexAge = df[ (df['Name'] == 'John Holland') | (df['Position'] == 'SG') ].index

# %%
merged_2
# Out:
#       fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 0      UR1US       US         0      1    480306     16769     860        0
# 1      UR1US       US         0      1    480309     29049     860        0
# 2      UR1US       US         0      1    480313     10372     860        0
# 3      UR1US       US         0      1    480316      5079     860        0
# 4      UR1US       US         0      1    480319     14649     860        0
# ...      ...      ...       ...    ...       ...       ...     ...      ...
# 32969  UR1US       US         0      1    590570        87     860        0
# 32970  UR1US       US         0      1    590573       819     860        0
# 32971  UR1US       US         0      1    590576      1460     860        0
# 32972  UR1US       US         0      1    590579        94     860        0
# 32973  UR1US       US         0      1    590582      2338     860        0
#
#        zcta5    arealand  ...          state stusab_y                  county  \
# 0      01001    29635470  ...  Massachusetts       MA                 Hampden
# 1      01002   142556362  ...  Massachusetts       MA               Hampshire
# 2      01003     1842384  ...  Massachusetts       MA               Hampshire
# 3      01005   114586903  ...  Massachusetts       MA               Worcester
# 4      01007   136345999  ...  Massachusetts       MA               Hampshire
# ...      ...         ...  ...            ...      ...                     ...
# 32969  99923    35937519  ...         Alaska       AK   Prince of Wales-Hyder
# 32970  99925   144503281  ...         Alaska       AK   Prince of Wales-Hyder
# 32971  99926   343947256  ...         Alaska       AK   Prince of Wales-Hyder
# 32972  99927   589688205  ...         Alaska       AK   Prince of Wales-Hyder
# 32973  99929  5598556684  ...         Alaska       AK  Wrangell-Petersburg (C
#
#        county_fips  community  community_code  latitude longitude accuracy  \
# 0             13.0        NaN             NaN   42.0702  -72.6227      4.0
# 1             15.0        NaN             NaN   42.3671  -72.4646      4.0
# 2             15.0        NaN             NaN   42.3919  -72.5248      4.0
# 3             27.0        NaN             NaN   42.4097  -72.1084      4.0
# 4             15.0        NaN             NaN   42.2751  -72.4110      4.0
# ...            ...        ...             ...       ...       ...      ...
# 32969        198.0        NaN             NaN   55.9169 -130.0247      1.0
# 32970        198.0        NaN             NaN   55.5526 -133.0555      4.0
# 32971        198.0        NaN             NaN   55.1215 -131.5790      4.0
# 32972        198.0        NaN             NaN   56.3528 -133.6211      4.0
# 32973        280.0        NaN             NaN   56.4335 -132.3529      4.0
#
#       zip3
# 0      010
# 1      010
# 2      010
# 3      010
# 4      010
# ...    ...
# 32969  999
# 32970  999
# 32971  999
# 32972  999
# 32973  999
#
# [32972 rows x 31 columns]

# %%
#merged_2['persons/housing unit'] = merged_2['pop100'] / merged_2['hu100']

# %%
merged_2
# Out:
#       fileid stusab_x  chariter  cifsn  logrecno  p0010001  sumlev  geocomp  \
# 0      UR1US       US         0      1    480306     16769     860        0
# 1      UR1US       US         0      1    480309     29049     860        0
# 2      UR1US       US         0      1    480313     10372     860        0
# 3      UR1US       US         0      1    480316      5079     860        0
# 4      UR1US       US         0      1    480319     14649     860        0
# ...      ...      ...       ...    ...       ...       ...     ...      ...
# 32969  UR1US       US         0      1    590570        87     860        0
# 32970  UR1US       US         0      1    590573       819     860        0
# 32971  UR1US       US         0      1    590576      1460     860        0
# 32972  UR1US       US         0      1    590579        94     860        0
# 32973  UR1US       US         0      1    590582      2338     860        0
#
#        zcta5    arealand  ...          state stusab_y                  county  \
# 0      01001    29635470  ...  Massachusetts       MA                 Hampden
# 1      01002   142556362  ...  Massachusetts       MA               Hampshire
# 2      01003     1842384  ...  Massachusetts       MA               Hampshire
# 3      01005   114586903  ...  Massachusetts       MA               Worcester
# 4      01007   136345999  ...  Massachusetts       MA               Hampshire
# ...      ...         ...  ...            ...      ...                     ...
# 32969  99923    35937519  ...         Alaska       AK   Prince of Wales-Hyder
# 32970  99925   144503281  ...         Alaska       AK   Prince of Wales-Hyder
# 32971  99926   343947256  ...         Alaska       AK   Prince of Wales-Hyder
# 32972  99927   589688205  ...         Alaska       AK   Prince of Wales-Hyder
# 32973  99929  5598556684  ...         Alaska       AK  Wrangell-Petersburg (C
#
#        county_fips  community  community_code  latitude longitude accuracy  \
# 0             13.0        NaN             NaN   42.0702  -72.6227      4.0
# 1             15.0        NaN             NaN   42.3671  -72.4646      4.0
# 2             15.0        NaN             NaN   42.3919  -72.5248      4.0
# 3             27.0        NaN             NaN   42.4097  -72.1084      4.0
# 4             15.0        NaN             NaN   42.2751  -72.4110      4.0
# ...            ...        ...             ...       ...       ...      ...
# 32969        198.0        NaN             NaN   55.9169 -130.0247      1.0
# 32970        198.0        NaN             NaN   55.5526 -133.0555      4.0
# 32971        198.0        NaN             NaN   55.1215 -131.5790      4.0
# 32972        198.0        NaN             NaN   56.3528 -133.6211      4.0
# 32973        280.0        NaN             NaN   56.4335 -132.3529      4.0
#
#       zip3
# 0      010
# 1      010
# 2      010
# 3      010
# 4      010
# ...    ...
# 32969  999
# 32970  999
# 32971  999
# 32972  999
# 32973  999
#
# [32972 rows x 31 columns]

# %%
summary_df = merged_2[['zip3','state','p0010001','arealand']]

# %%
summary_df = summary_df.groupby(['zip3','state'])[['p0010001','arealand']].sum()

# %%
#summary_df.reset_index(inplace=True,drop=True)
summary_df.reset_index(level=['zip3','state'],inplace=True)
summary_df
# Out:
#     zip3          state  p0010001      arealand
# 0    010  Massachusetts    469375    3280116609
# 1    011  Massachusetts    168835     106083030
# 2    012  Massachusetts    130689    2360467856
# 3    013  Massachusetts     83111    2029083678
# 4    014  Massachusetts    211812    1231149054
# ..   ...            ...       ...           ...
# 886  995         Alaska    320660  149810726268
# 887  996         Alaska    184083  138819400255
# 888  997         Alaska    134189  261368179739
# 889  998         Alaska     49595   35487047529
# 890  999         Alaska     21403   25345328487
#
# [891 rows x 4 columns]

# %%
summary_df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#e(i) - There are 13 3 digit zips between 10 and 19,999 residents
small_df = summary_df[ (summary_df['p0010001'] >= 10) & (summary_df['p0010001'] < 20000) ]
len(small_df)
# Out:
# 13

# %%
#small_df['density'] = small_df['arealand'] /small_df['p0010001']
small_df['Persons / 100M land units'] = (small_df['p0010001'] / small_df['arealand'] ) * 100000000
#small_df['density'].sort_values(ascending=False).round(0)
small_df = small_df.sort_values(by = 'Persons / 100M land units', ascending=True).round(1)

# %%
small_df
# Out:
#     zip3                 state  p0010001     arealand  \
# 746  821               Wyoming       369   7698493836
# 798  893                Nevada     12103  18040900958
# 795  884            New Mexico     17370  25465767488
# 633  692              Nebraska      8637  12215685056
# 789  878            New Mexico     18552  24362674732
# 748  823               Wyoming     16430  13883818454
# 510  556             Minnesota     16024   7788672063
# 790  879            New Mexico     17432   7110318330
# 48   059               Vermont      3525   1168172499
# 338  369               Alabama     19164   3159815117
# 26   036         New Hampshire     13759    525626811
# 181  203  District of Columbia      1702      2489901
# 81   102              New York     12636       636442
#
#      Persons / 100M land units
# 746                        4.8
# 798                       67.1
# 795                       68.2
# 633                       70.7
# 789                       76.1
# 748                      118.3
# 510                      205.7
# 790                      245.2
# 48                       301.8
# 338                      606.5
# 26                      2617.6
# 181                    68356.1
# 81                   1985412.7

# %%
small_df_no_NYDC = small_df[(small_df['state'] != 'New York') & (small_df['state'] != 'District of Columbia')]

# %%
small_df_NYDC = small_df[(small_df['state'] == 'New York') | (small_df['state'] == 'District of Columbia')]

# %%
small_df_no_NYDC.sort_values(by = 'Persons / 100M land units' ,ascending = False)
#small_df_2.reset_index(inplace=True)
#small_df
# Out:
#     zip3          state  p0010001     arealand  Persons / 100M land units
# 26   036  New Hampshire     13759    525626811                     2617.6
# 338  369        Alabama     19164   3159815117                      606.5
# 48   059        Vermont      3525   1168172499                      301.8
# 790  879     New Mexico     17432   7110318330                      245.2
# 510  556      Minnesota     16024   7788672063                      205.7
# 748  823        Wyoming     16430  13883818454                      118.3
# 789  878     New Mexico     18552  24362674732                       76.1
# 633  692       Nebraska      8637  12215685056                       70.7
# 795  884     New Mexico     17370  25465767488                       68.2
# 798  893         Nevada     12103  18040900958                       67.1
# 746  821        Wyoming       369   7698493836                        4.8

# %%
#e(ii) DC and New York split onto separate bar chart due to drastic difference in population density and for readability of chart.
#NH is fairly dense compared to other small zips but more in line with zips not in dense urban areas.

fig, ax = plt.subplots(figsize=(15, 6))
#sns.barplot(x="total", y="abbrev", data=crashes)

# new helper method to auto-label bars
#small_df_2.sort_values(by = 'Persons / 100M land units' ,ascending = False)
sns.barplot(data=small_df_no_NYDC, y = 'zip3', x = 'Persons / 100M land units', order = small_df_no_NYDC.sort_values('Persons / 100M land units').zip3) 
ax.bar_label(ax.containers[0])
plt.show()

fig, ax = plt.subplots(figsize=(15, 6))
sns.barplot(data=small_df_NYDC, y = 'zip3', x = 'Persons / 100M land units', order = small_df_NYDC.sort_values('Persons / 100M land units').zip3) 
ax.bar_label(ax.containers[0])
plt.show()

# %%
#e(iii) The 3 digit zip of 821 has the smallest population density - this is somewhat surprising as I would have guessed Alaska.
#small_df['density'] = small_df['arealand'] /small_df['p0010001']
#small_df['density'].sort_values(ascending=False).round(0)
small_df.sort_values(by = 'Persons / 100M land units', ascending=True).round(0)
# Out:
#     zip3                 state  p0010001     arealand  \
# 746  821               Wyoming       369   7698493836
# 798  893                Nevada     12103  18040900958
# 795  884            New Mexico     17370  25465767488
# 633  692              Nebraska      8637  12215685056
# 789  878            New Mexico     18552  24362674732
# 748  823               Wyoming     16430  13883818454
# 510  556             Minnesota     16024   7788672063
# 790  879            New Mexico     17432   7110318330
# 48   059               Vermont      3525   1168172499
# 338  369               Alabama     19164   3159815117
# 26   036         New Hampshire     13759    525626811
# 181  203  District of Columbia      1702      2489901
# 81   102              New York     12636       636442
#
#      Persons / 100M land units
# 746                        5.0
# 798                       67.0
# 795                       68.0
# 633                       71.0
# 789                       76.0
# 748                      118.0
# 510                      206.0
# 790                      245.0
# 48                       302.0
# 338                      606.0
# 26                      2618.0
# 181                    68356.0
# 81                   1985413.0

# %%
#confirming answer above is not Alaska cuz pop requirements
summary_df['Persons / 100M land units'] = (summary_df['p0010001'] / summary_df['arealand'] ) * 100000000
summary_df[summary_df['state'] == 'Alaska'].sort_values(by = 'Persons / 100M land units',ascending = False).round(0)
# Out:
#     zip3   state  p0010001      arealand  Persons / 100M land units
# 886  995  Alaska    320660  149810726268                      214.0
# 889  998  Alaska     49595   35487047529                      140.0
# 887  996  Alaska    184083  138819400255                      133.0
# 890  999  Alaska     21403   25345328487                       84.0
# 888  997  Alaska    134189  261368179739                       51.0

# %%
#sns.histplot(data=merged_2,x='zip',y='pop100',bins = 5)

# %%
#f - overview of population distribution for 5 digit zips
#sns.histplot(data=merged_2,x='zip',y='pop100')
merged_2.describe()
# Out:
#        chariter    cifsn       logrecno       p0010001   sumlev  geocomp  \
# count   32972.0  32972.0   32972.000000   32972.000000  32972.0  32972.0
# mean        0.0      1.0  535264.705963    9363.254246    860.0      0.0
# std         0.0      0.0   32455.205043   13670.127639      0.0      0.0
# min         0.0      1.0  480306.000000       0.000000    860.0      0.0
# 25%         0.0      1.0  506568.000000     733.000000    860.0      0.0
# 50%         0.0      1.0  535184.500000    2778.000000    860.0      0.0
# 75%         0.0      1.0  563798.000000   12811.000000    860.0      0.0
# max         0.0      1.0  590582.000000  113916.000000    860.0      0.0
#
#            arealand      areawatr         pop100         hu100      intptlat  \
# count  3.297200e+04  3.297200e+04   32972.000000  32972.000000  32972.000000
# mean   2.250865e+08  5.120114e+06    9363.254246   3993.982106     38.916202
# std    6.575867e+08  3.314201e+07   13670.127639   5551.956392      5.210680
# min    5.094000e+03  0.000000e+00       0.000000      0.000000     19.064517
# 25%    2.354113e+07  5.795600e+04     733.000000    364.000000     35.458384
# 50%    9.327648e+07  5.797135e+05    2778.000000   1317.000000     39.529973
# 75%    2.305539e+08  2.765582e+06   12811.000000   5586.250000     42.131760
# max    3.478610e+10  2.476574e+09  113916.000000  47617.000000     71.254083
#
#            intptlon   county_fips  community_code      latitude     longitude  \
# count  32972.000000  32970.000000             1.0  32972.000000  32972.000000
# mean     -91.116143     84.905247         47280.0     38.915023    -91.116631
# std       15.084655     85.772864             NaN      5.206040     15.087276
# min     -176.629994      1.000000         47280.0     19.066800   -176.634000
# 25%      -97.274053     27.000000         47280.0     35.454075    -97.275425
# 50%      -88.265090     67.000000         47280.0     39.528350    -88.261900
# 75%      -80.310621    115.000000         47280.0     42.126600    -80.309350
# max      -67.008913    840.000000         47280.0     71.234600    -67.007400
#
#            accuracy
# count  32972.000000
# mean       3.916293
# std        0.494088
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        4.000000
# max        4.000000

# %%
#overview of population distribution for 3 digit zips
#as expected, higher mean for 3 digit zips as they are a combination of many different 5 digit zip codes 
#37 5-digit zip codes per 3-digit zip on average (32,972/891)
summary_df.describe().round(0)
# Out:
#         p0010001      arealand  Persons / 100M land units
# count      891.0  8.910000e+02                      891.0
# mean    346492.0  8.329463e+09                    51982.0
# std     372946.0  1.406425e+10                   206108.0
# min          0.0  1.339200e+04                        0.0
# 25%     116034.0  1.049466e+09                     1700.0
# 50%     212201.0  5.001696e+09                     4810.0
# 75%     441237.0  1.069824e+10                    33053.0
# max    2906700.0  2.613682e+11                  3873153.0

# %%
#Side by side boxplots - Left side is zip3 distribuion and right side is 5 digit zip distribution
fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.boxplot(data = summary_df, y='p0010001',ax=axes[0])
sns.boxplot(data = merged_2, y='p0010001',ax=axes[1])
# Out:
# <AxesSubplot:ylabel='p0010001'>

# %% [markdown]
# 1. As expected, there is a higher mean population for 3-digit zips as they are a combination of many different 5-digit zip codes. On average, there are 37 5-digit zip codes per 3-digit zip (32,972/891). </br></br>
#
# 2. In both cases, outliers are skewed towards higher values but that is due to nature of the data with the floor of an observation value being 0. There are more outliers on the 5-digit zip plot but also more observations. </br></br>
#
# 3. 5-digit zip populations are more positively skewed as the median is comparatively closer to the bottom of the IQR. </br></br>
#
# 4. There is a wider range of population values at the 3-digit zip level as the whiskers are longer than the ones for the 5-digit plot.

# %%
#summary_df['p0010001'].to_frame('data').boxplot()

# %% [markdown]
# Generally speaking, it is assumed that there would be a positive relationship between population size and the number of housing units needed. </br>This is confirmed by the below plot.

# %%
sns.lmplot(data=merged_2,x='pop100',y='hu100')
plt.show()

# %%
#sns.histplot(data=summary_df,x='zip3',y='p0010001',bins=5)

# %%
#merged_2.info()

# %%
#merged.loc[31391,:]

# %%
#merged.groupby('zip3')['state'].nunique().sort_values(ascending=False)

# %%
#merged.groupby(['zip3','state'])['state'].count()

# %%
#merged.groupby('zip3')['state'].nunique().sort_values(ascending=False)

# %%
#merged.groupby('zip3')['state'].count().sort_values(ascending=False)

# %%
#temp = merged.groupby('zip3').nunique().sort_values(by='state',ascending=False)

# %%
#temp[temp['state'] == 2]

# %%
#temp.apply(print)

# %%
# for i in range(0,len(temp)-1):
#     if temp[i]

# %%
# merged.groupby(['zip3','state'])['state'].count().nunique()

# %%
#merged.groupby('zip3').count().sort_values(by ='zip3',ascending=False)
